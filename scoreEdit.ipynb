# %%
f = open("myNewRankedLists.txt","r")
f1 = f.readlines()
ans = {}
for x in f1:
    print(x)
    y = x.split()
    value = y[6]
    z = x.split('_')
    q = z[2]
    i = z[0]
    i = i.split()
    i = i[4]
    q = q.split()
    q = q[0]
    if q not in ans:
        ans[q] = []
    ans[q].append([y[6],i])
        
for key in ans.keys():
    print(key)
    cnt = 10
#     print(ans[key])
    ans[key].sort()
    #print(ans[key])
    val = []
    li = []
    for i in ans[key]:
        if i[0] not in val:
            cnt = cnt - 1
            val.append(i[0])
        li.append([i[1],cnt])
    print(li)
# Out:
# 1 Q0 docid = 71_of_INDvAUS 1 -53.98097 indri
#
# 1 Q0 docid = 94_of_INDvAUS 2 -53.98097 indri
#
# 1 Q0 docid = 101_of_INDvAUS 3 -53.98097 indri
#
# 1 Q0 docid = 138_of_INDvAUS 4 -53.98097 indri
#
# 1 Q0 docid = 162_of_INDvAUS 5 -53.98097 indri
#
# 1 Q0 docid = 163_of_INDvAUS 6 -53.98097 indri
#
# 1 Q0 docid = 164_of_INDvAUS 7 -53.98097 indri
#
# 1 Q0 docid = 165_of_INDvAUS 8 -53.98097 indri
#
# 1 Q0 docid = 166_of_INDvAUS 9 -53.98097 indri
#
# 1 Q0 docid = 167_of_INDvAUS 10 -53.98097 indri
#
# 1 Q0 docid = 168_of_INDvAUS 11 -53.98097 indri
#
# 1 Q0 docid = 187_of_INDvAUS 12 -53.98097 indri
#
# 1 Q0 docid = 190_of_INDvAUS 13 -53.98097 indri
#
# 1 Q0 docid = 196_of_INDvAUS 14 -53.98097 indri
#
# 1 Q0 docid = 197_of_INDvAUS 15 -53.98097 indri
#
# 1 Q0 docid = 205_of_INDvAUS 16 -53.98097 indri
#
# 1 Q0 docid = 224_of_INDvAUS 17 -53.98097 indri
#
# 1 Q0 docid = 228_of_INDvAUS 18 -53.98097 indri
#
# 1 Q0 docid = 243_of_INDvAUS 19 -53.98097 indri
#
# ...

# %%
s = "docid = 12_of_abab 993"
x = s.split('_')
a = {}
if x[1] not in a:
    a[x[1]] = []
    a[x[1]].append(x)
    a[x[1]].append("asa")
print(a)
# Out:
# {'of': [['docid = 12', 'of', 'abab 993'], 'asa']}
