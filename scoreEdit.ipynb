# %%
f = open("myNewRankedLists.txt","r")
f1 = f.readlines()
ans = {}
for x in f1:
#     print(x)
    y = x.split()
#     print(y)
    z = x.split('_')
    q = z[2]
    i = z[0]
    i = i.split()
    i = i[4]
    q = q.split()
    q = q[0]
#     print("yey"+y[6]+" "+i)
    if q not in ans:
        ans[q] = []
    ans[q].append([float(y[6]),float(i)])
        
for key in ans.keys():
    print(key)
    cnt = 10
#     print(ans[key])
    ans[key].sort()
#     print(ans[key])
    val = []
    li = []
    for i in ans[key]:
        if i[0] not in val:
            cnt = cnt - 1
            val.append(i[0])
        li.append([i[1],cnt])
    print(li)
# Out:
# narendra
# ...

# %%
s = "docid = 12_of_abab 993"
x = s.split('_')
a = {}
if x[1] not in a:
    a[x[1]] = []
    a[x[1]].append(x)
    a[x[1]].append("asa")
print(a)
# Out:
# {'of': [['docid = 12', 'of', 'abab 993'], 'asa']}
